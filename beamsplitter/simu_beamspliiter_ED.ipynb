# %%
import qutip as qt
import numpy as np
import matplotlib.pyplot as plt
from qutip.ipynbtools import version_table
from tqdm.notebook import tqdm
from matplotlib.animation import FuncAnimation
from scipy.linalg import expm
import pandas as pd

resol = 200
pi = np.pi
version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>5.1.1</td></tr><tr><td>Numpy</td><td>1.26.2</td></tr><tr><td>SciPy</td><td>1.11.3</td></tr><tr><td>matplotlib</td><td>3.7.3</td></tr><tr><td>Number of CPUs</td><td>11</td></tr><tr><td>BLAS Info</td><td>Generic</td></tr><tr><td>IPython</td><td>8.17.2</td></tr><tr><td>Python</td><td>3.12.0 (v3.12.0:0fb18b02c8, Oct  2 2023, 09:45:56) [Clang 13.0.0 (clang-1300.0.29.30)]</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td>Cython</td><td>3.0.11</td></tr><tr><td colspan='2'>Thu Sep 11 18:09:19 2025 JST</td></tr></table>

# %% [markdown]
# <h1> Perform time evolution </h1>

# %%
def bs_evolution(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, delta_x, use_WW_approx = True, print_nb_modes = False):
    
    #quantization of the modes by keeping only a portion of them
    #omega_tab_p = np.linspace(0, omega_max , nb_omega)
    omega_tab_p = np.array([2*pi*n/L for n in range(1000000) if 2*pi*n/L <= omega_max])
    
    k_tab = np.sort(np.unique(np.concatenate((-omega_tab_p, omega_tab_p))))
    #k_tab = np.copy(omega_tab_p)
    #keep only a portion of the modes 
    omega_tab = np.abs(k_tab)
    n_modes = len(k_tab)

    if print_nb_modes:
        print("Number of modes: ", n_modes)
    
    #create the Hamiltonian
    dim_subspace = n_modes * (2*n_modes + 1) + 2*n_modes
    if print_nb_modes:
        print("Dimension of the subspace: ", dim_subspace)

    
    print("Generating the Hamiltonian...")
    #tab with the coupling parameters
    g_tab = np.zeros(n_modes, dtype=complex)
    for i in range(n_modes):
            if use_WW_approx:
                g_tab[i] = g_0*np.sqrt(omega_A/L)*1j
            else:
                g_tab[i] = g_0*np.sqrt(omega_tab[i]/L)*1j #in my case, g is independant of the atom index


    #now define the Hamiltonian
    H_matrix = np.zeros((dim_subspace, dim_subspace), dtype=complex)
    index = 0 #dummy way to do it but I'm struggling to find a direct mapping

    ###Diagonal elements

    #diagonal elements with two photons in the horizontal direction
    for i in range(n_modes):
        for j in range(i, n_modes):
            H_matrix[index, index] = omega_tab[i] + omega_tab[j]
            index += 1

    #diagonal elements with two photons in the vertical direction
    for i in range(n_modes):
        for j in range(i, n_modes):
            H_matrix[index, index] = omega_tab[i] + omega_tab[j]
            index += 1
            
    #diagonal elements with two photons in distinct directions
    for i in range(n_modes**2):
        H_matrix[index,index] = omega_tab[int(i//n_modes)] + omega_tab[int(i%n_modes)]
        index += 1

    #diagonal elements with one horizontal photon and one excited atom
    for i in range(n_modes):
        H_matrix[index,index] = omega_tab[i] + omega_A
        index += 1

    #diagonal elements with one vertical photon and the atom
    for i in range(n_modes):
        H_matrix[index,index] = omega_tab[i] + omega_A
        index += 1

    ## Off diagonal elements

    #|2,0,0> <-> |1,0,1>
    dummy_index_0 = 0
    for i in range(n_modes):
        for j in range(i, n_modes):
            dummy_index_1 = n_modes*(2*n_modes + 1)
            for k in range(n_modes):
                if k == i:
                    if i == j:
                        H_matrix[dummy_index_1, dummy_index_0] = np.sqrt(2)*np.conjugate(g_tab[j])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                    else:
                        H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[j])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                if k == j:
                    if i == j:
                        H_matrix[dummy_index_1, dummy_index_0] = np.sqrt(2)*np.conjugate(g_tab[i])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                    else:
                        H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[i])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])

                dummy_index_1 += 1
            dummy_index_0 += 1

    #|0,2,0> <-> |0,1,1>
    dummy_index_0 = n_modes*(n_modes + 1)//2
    for i in range(n_modes):
        for j in range(i, n_modes):
            dummy_index_1 = n_modes*(2*n_modes + 1) + n_modes
            for k in range(n_modes):
                if k == i:
                    if i == j:
                        H_matrix[dummy_index_1, dummy_index_0] = np.sqrt(2)*np.conjugate(g_tab[j])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                    else:
                        H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[j])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                if k == j:
                    if i == j:
                        H_matrix[dummy_index_1, dummy_index_0] = np.sqrt(2)*np.conjugate(g_tab[i])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                    else:
                        H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[i])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])

                dummy_index_1 += 1
            dummy_index_0 += 1

    #|1,1,0> <-> |1,0,1>
    dummy_index_0 = n_modes*(n_modes + 1)
    for i in range(n_modes):
        for j in range(n_modes):
            dummy_index_1 = n_modes*(2*n_modes + 1) 
            for k in range(n_modes):
                if k == i:
                    H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[j])
                    H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                if k == j:
                        H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[i])
                        H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                                
                dummy_index_1 += 1
            dummy_index_0 += 1
        
    #|1,1,0> <-> |0,1,1>
    dummy_index_0 = n_modes*(n_modes + 1)
    for i in range(n_modes):
        for j in range(n_modes):
            dummy_index_1 = n_modes*(2*n_modes + 1) + n_modes
            for k in range(n_modes):
                if k == i:
                    H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[j])
                    H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                if k == j:
                    H_matrix[dummy_index_1, dummy_index_0] = np.conjugate(g_tab[i])
                    H_matrix[dummy_index_0, dummy_index_1] = np.conjugate(H_matrix[dummy_index_1, dummy_index_0])
                                
                dummy_index_1 += 1
            dummy_index_0 += 1

    H = qt.Qobj(H_matrix)

    #hermicity check
    if not H.isherm:
        print("Warning: the Hamiltonian is not hermitian")
        return None
    

    #also get the free Hamiltonian
    H_free = qt.Qobj(np.diag(np.diag(H_matrix)))

    print("Preparing the initial state...")
    ##Now prepare the initial state
    x_0_a = x_0
    x_0_b = x_0 + delta_x

    init_state = 0
    for i in range(n_modes**2):
        k_a = k_tab[int(i//n_modes)]
        k_b = k_tab[int(i%n_modes)]
        #if k_a > 0 and k_b > 0:
        c_a = np.exp(-0.5*sigma**2*(k_a - omega_0)**2 -1j * k_a * x_0_a)
        c_b = np.exp(-0.5*sigma**2*(k_b - omega_0)**2 -1j * k_b * x_0_b)
        init_state += c_a * c_b * qt.basis(dim_subspace, n_modes*(n_modes+1) + i)

    init_state = init_state.unit()


    print("Conducting time evolution...")
    ##Conduct time evolution
    n_step = int(T/dt)
    times = np.linspace(0, T, n_step)
    result = qt.sesolve(H, init_state, times, options={"nsteps":10000, "progress_bar": True, "store_states": True})
    state_list = result.states

    print("Conducting free evolution...")
    #also get the free evolution of the initial state
    result_free = qt.sesolve(H_free, init_state, times, options={"nsteps":10000, "store_states": True, "progress_bar": True})
    state_list_free = result_free.states
    print("Done.")

    return state_list, state_list_free, k_tab, times

# %%
L = 5*pi
T = L/2
dt = 0.1

#Jaynes-Cummings parameter g_0 and energies 
g_0 = 1
omega_A = 3
omega_0 = 6.7
omega_max = 10

#initial photon wavepacket parameters
sigma = L/16
sigma_momentum = 1/sigma
x_0 = -L/4
delta_x = 0*sigma

#check some parameters
gamma = g_0**2 * omega_A
print("50% Reflectivity for omega_0_m = ", omega_A - gamma, " and omega_0_p = ", omega_A + gamma)
# Out:
# 50% Reflectivity for omega_0_m =  0  and omega_0_p =  6

# %%
#conduct the evolution
state_list, state_list_free, k_tab, times = bs_evolution(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, delta_x, use_WW_approx = True, print_nb_modes = True)
# Out:
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   1.11s. Est. time left: 00:00:00:09
# 20.8%. Run time:   2.07s. Est. time left: 00:00:00:07
# 31.2%. Run time:   2.97s. Est. time left: 00:00:00:06
# 40.3%. Run time:   3.72s. Est. time left: 00:00:00:05
# 50.6%. Run time:   4.59s. Est. time left: 00:00:00:04
# 61.0%. Run time:   5.47s. Est. time left: 00:00:00:03
# 70.1%. Run time:   6.24s. Est. time left: 00:00:00:02
# 80.5%. Run time:   7.11s. Est. time left: 00:00:00:01
# 90.9%. Run time:   7.98s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.74s. Est. time left: 00:00:00:00
# Total run time:   8.74s
# Conducting free evolution...
# 10.4%. Run time:   0.59s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.08s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.58s. Est. time left: 00:00:00:03
# 40.3%. Run time:   2.01s. Est. time left: 00:00:00:02
# 50.6%. Run time:   2.50s. Est. time left: 00:00:00:02
# 61.0%. Run time:   2.99s. Est. time left: 00:00:00:01
# 70.1%. Run time:   3.42s. Est. time left: 00:00:00:01
# 80.5%. Run time:   3.92s. Est. time left: 00:00:00:00
# 90.9%. Run time:   4.40s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.84s. Est. time left: 00:00:00:00
# Total run time:   4.84s
# Done.

# %%
nb_pts_time = len(times)
n_modes = len(k_tab)
n_modes * (2*n_modes + 1) + 2*n_modes

overlap = np.zeros(nb_pts_time)
atom_occupation = np.zeros(nb_pts_time)

for i in tqdm(range(nb_pts_time)):
    current_state = state_list[i]
    current_state_free = state_list_free[i]
   
    overlap[i] = np.abs(current_state.dag() * current_state_free)**2
    atom_occupation[i] = 0
    for j in range(n_modes):
        atom_occupation[i] += np.abs(current_state[n_modes*(2*n_modes + 1) + j][0])**2
# Out:
#   0%|          | 0/78 [00:00<?, ?it/s]

# %%
print("Final overlap with the free evolution: ", overlap[-1])
print("Theory value: ", 0.5*(1- np.exp(- (delta_x**2) / (2*sigma**2))))

fig, ax = plt.subplots(1,1, figsize=(3,3), dpi=resol)
ax.plot(times, overlap, label="Overlap with free evolution")
ax.plot(times, atom_occupation, label="Atom occupation")
ax.set_xlabel("Time")
ax.set_ylabel("Probability")
ax.grid()
ax.legend()
plt.show()
# Out:
# Final overlap with the free evolution:  0.06230140135469851
# Theory value:  0.0

# %% [markdown]
# <h1> Try to visualize the photonic wave function </h1>

# %%
c_to_show = np.zeros((2*n_modes, 2*n_modes), dtype=complex)
current_state = state_list[50][:n_modes*(2*n_modes+1)]

dummy_index = 0
for i in range(n_modes):
    for j in range(i,n_modes):
        c_to_show[i,j] = current_state[dummy_index]
        dummy_index += 1

for i in range(n_modes):
    for j in range(i,n_modes):
        c_to_show[n_modes+i,n_modes+j] = current_state[dummy_index]
        dummy_index += 1

for i in range(n_modes):
    for j in range(n_modes):
        c_to_show[i,n_modes+j] = current_state[dummy_index]
        dummy_index += 1
# Out:
# /var/folders/ds/7w970h197d59hh_2dj4ry5qw0000gn/T/ipykernel_1192/2310814259.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   c_to_show[i,j] = current_state[dummy_index]
# /var/folders/ds/7w970h197d59hh_2dj4ry5qw0000gn/T/ipykernel_1192/2310814259.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   c_to_show[n_modes+i,n_modes+j] = current_state[dummy_index]
# /var/folders/ds/7w970h197d59hh_2dj4ry5qw0000gn/T/ipykernel_1192/2310814259.py:17: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   c_to_show[i,n_modes+j] = current_state[dummy_index]

# %%
fig, ax = plt.subplots(1,1, figsize=(3,3), dpi=resol)
im = ax.imshow(np.abs(c_to_show)**2)
plt.colorbar(im, ax=ax)
#clear labels over axis

plt.show()

# %% [markdown]
# <h1> Reproduce a HOM effect </h1>

# %%
L = 5*pi
T = L/2
dt = 0.1

#Jaynes-Cummings parameter g_0 and energies 
g_0 = 1
omega_A = 3
omega_0 = 8
omega_max = 10

#initial photon wavepacket parameters
sigma = L/16
sigma_momentum = 1/sigma
x_0 = -L/4

#prepare several values of delta_x
nb_pts_x = 9
delta_x_tab = np.linspace(-3*sigma, 3*sigma, nb_pts_x)
final_overlap_free_tab = np.zeros(nb_pts_x)

for i in tqdm(range(nb_pts_x)):
    delta_x = delta_x_tab[i]
    state_list, state_list_free, k_tab, times = bs_evolution(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, delta_x, use_WW_approx = True, print_nb_modes = True)
    final_overlap_free_tab[i] = np.abs(state_list_free[-1].dag() * state_list[-1])**2
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.71s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.36s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.00s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.55s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.21s. Est. time left: 00:00:00:03
# 61.0%. Run time:   3.84s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.40s. Est. time left: 00:00:00:01
# 80.5%. Run time:   5.05s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.74s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.30s. Est. time left: 00:00:00:00
# Total run time:   6.30s
# Conducting free evolution...
# 10.4%. Run time:   0.69s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.31s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.92s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.45s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.06s. Est. time left: 00:00:00:02
# 61.0%. Run time:   3.69s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.23s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.82s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.41s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.95s. Est. time left: 00:00:00:00
# Total run time:   5.95s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.66s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.28s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.88s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.44s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.09s. Est. time left: 00:00:00:03
# 61.0%. Run time:   3.72s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.28s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.92s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.54s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.09s. Est. time left: 00:00:00:00
# Total run time:   6.09s
# Conducting free evolution...
# 10.4%. Run time:   0.66s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.24s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.82s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.33s. Est. time left: 00:00:00:03
# 50.6%. Run time:   2.93s. Est. time left: 00:00:00:02
# 61.0%. Run time:   3.52s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.08s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.66s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.25s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.77s. Est. time left: 00:00:00:00
# Total run time:   5.77s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   1.05s. Est. time left: 00:00:00:09
# 20.8%. Run time:   2.05s. Est. time left: 00:00:00:07
# 31.2%. Run time:   3.06s. Est. time left: 00:00:00:06
# 40.3%. Run time:   3.94s. Est. time left: 00:00:00:05
# 50.6%. Run time:   4.93s. Est. time left: 00:00:00:04
# 61.0%. Run time:   5.93s. Est. time left: 00:00:00:03
# 70.1%. Run time:   6.81s. Est. time left: 00:00:00:02
# 80.5%. Run time:   7.84s. Est. time left: 00:00:00:01
# 90.9%. Run time:   8.88s. Est. time left: 00:00:00:00
# 100.0%. Run time:  10.13s. Est. time left: 00:00:00:00
# Total run time:  10.13s
# Conducting free evolution...
# 10.4%. Run time:   0.97s. Est. time left: 00:00:00:08
# 20.8%. Run time:   1.99s. Est. time left: 00:00:00:07
# 31.2%. Run time:   2.66s. Est. time left: 00:00:00:05
# 40.3%. Run time:   3.21s. Est. time left: 00:00:00:04
# 50.6%. Run time:   3.84s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.50s. Est. time left: 00:00:00:02
# 70.1%. Run time:   5.07s. Est. time left: 00:00:00:02
# 80.5%. Run time:   5.69s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.40s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.97s. Est. time left: 00:00:00:00
# Total run time:   6.97s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   1.42s. Est. time left: 00:00:00:12
# 20.8%. Run time:   2.76s. Est. time left: 00:00:00:10
# 31.2%. Run time:   4.08s. Est. time left: 00:00:00:09
# 40.3%. Run time:   5.78s. Est. time left: 00:00:00:08
# 50.6%. Run time:   7.13s. Est. time left: 00:00:00:06
# 61.0%. Run time:   8.50s. Est. time left: 00:00:00:05
# 70.1%. Run time:  10.00s. Est. time left: 00:00:00:04
# 80.5%. Run time:  11.49s. Est. time left: 00:00:00:02
# 90.9%. Run time:  12.68s. Est. time left: 00:00:00:01
# 100.0%. Run time:  14.17s. Est. time left: 00:00:00:00
# Total run time:  14.20s
# Conducting free evolution...
# 10.4%. Run time:   0.86s. Est. time left: 00:00:00:07
# 20.8%. Run time:   1.57s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.20s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.88s. Est. time left: 00:00:00:04
# 50.6%. Run time:   3.56s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.22s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.76s. Est. time left: 00:00:00:02
# 80.5%. Run time:   5.39s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.01s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.58s. Est. time left: 00:00:00:00
# Total run time:   6.58s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.71s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.34s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.00s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.61s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.47s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.37s. Est. time left: 00:00:00:02
# 70.1%. Run time:   5.11s. Est. time left: 00:00:00:02
# 80.5%. Run time:   5.95s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.81s. Est. time left: 00:00:00:00
# 100.0%. Run time:   7.70s. Est. time left: 00:00:00:00
# Total run time:   7.70s
# Conducting free evolution...
# 10.4%. Run time:   0.67s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.40s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.34s. Est. time left: 00:00:00:05
# 40.3%. Run time:   2.95s. Est. time left: 00:00:00:04
# 50.6%. Run time:   3.62s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.28s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.84s. Est. time left: 00:00:00:02
# 80.5%. Run time:   5.47s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.13s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.69s. Est. time left: 00:00:00:00
# Total run time:   6.69s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.78s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.63s. Est. time left: 00:00:00:06
# 31.2%. Run time:   2.39s. Est. time left: 00:00:00:05
# 40.3%. Run time:   3.09s. Est. time left: 00:00:00:04
# 50.6%. Run time:   4.18s. Est. time left: 00:00:00:04
# 61.0%. Run time:   5.19s. Est. time left: 00:00:00:03
# 70.1%. Run time:   6.04s. Est. time left: 00:00:00:02
# 80.5%. Run time:   6.94s. Est. time left: 00:00:00:01
# 90.9%. Run time:   7.83s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.67s. Est. time left: 00:00:00:00
# Total run time:   8.67s
# Conducting free evolution...
# 10.4%. Run time:   0.69s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.28s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.95s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.57s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.20s. Est. time left: 00:00:00:03
# 61.0%. Run time:   3.82s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.38s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.97s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.62s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.16s. Est. time left: 00:00:00:00
# Total run time:   6.16s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.77s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.45s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.12s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.80s. Est. time left: 00:00:00:04
# 50.6%. Run time:   3.66s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.64s. Est. time left: 00:00:00:02
# 70.1%. Run time:   5.73s. Est. time left: 00:00:00:02
# 80.5%. Run time:   6.64s. Est. time left: 00:00:00:01
# 90.9%. Run time:   7.72s. Est. time left: 00:00:00:00
# 100.0%. Run time:   8.63s. Est. time left: 00:00:00:00
# Total run time:   8.63s
# Conducting free evolution...
# 10.4%. Run time:   0.74s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.42s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.07s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.70s. Est. time left: 00:00:00:04
# 50.6%. Run time:   3.38s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.04s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.65s. Est. time left: 00:00:00:01
# 80.5%. Run time:   5.38s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.05s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.63s. Est. time left: 00:00:00:00
# Total run time:   6.63s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   1.15s. Est. time left: 00:00:00:09
# 20.8%. Run time:   2.33s. Est. time left: 00:00:00:08
# 31.2%. Run time:   3.52s. Est. time left: 00:00:00:07
# 40.3%. Run time:   4.55s. Est. time left: 00:00:00:06
# 50.6%. Run time:   5.69s. Est. time left: 00:00:00:05
# 61.0%. Run time:   6.82s. Est. time left: 00:00:00:04
# 70.1%. Run time:   7.79s. Est. time left: 00:00:00:03
# 80.5%. Run time:   9.36s. Est. time left: 00:00:00:02
# 90.9%. Run time:  10.40s. Est. time left: 00:00:00:01
# 100.0%. Run time:  11.31s. Est. time left: 00:00:00:00
# Total run time:  11.31s
# Conducting free evolution...
# 10.4%. Run time:   0.69s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.30s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.92s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.44s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.14s. Est. time left: 00:00:00:03
# 61.0%. Run time:   3.81s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.34s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.94s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.53s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.09s. Est. time left: 00:00:00:00
# Total run time:   6.09s
# Done.
# Number of modes:  51
# Dimension of the subspace:  5355
# Generating the Hamiltonian...
# Preparing the initial state...
# Conducting time evolution...
# 10.4%. Run time:   0.75s. Est. time left: 00:00:00:06
# 20.8%. Run time:   1.42s. Est. time left: 00:00:00:05
# 31.2%. Run time:   2.10s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.68s. Est. time left: 00:00:00:03
# 50.6%. Run time:   3.38s. Est. time left: 00:00:00:03
# 61.0%. Run time:   4.06s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.65s. Est. time left: 00:00:00:01
# 80.5%. Run time:   5.36s. Est. time left: 00:00:00:01
# 90.9%. Run time:   6.06s. Est. time left: 00:00:00:00
# 100.0%. Run time:   6.69s. Est. time left: 00:00:00:00
# Total run time:   6.70s
# Conducting free evolution...
# 10.4%. Run time:   0.67s. Est. time left: 00:00:00:05
# 20.8%. Run time:   1.27s. Est. time left: 00:00:00:04
# 31.2%. Run time:   1.85s. Est. time left: 00:00:00:04
# 40.3%. Run time:   2.35s. Est. time left: 00:00:00:03
# 50.6%. Run time:   2.93s. Est. time left: 00:00:00:02
# 61.0%. Run time:   3.57s. Est. time left: 00:00:00:02
# 70.1%. Run time:   4.08s. Est. time left: 00:00:00:01
# 80.5%. Run time:   4.67s. Est. time left: 00:00:00:01
# 90.9%. Run time:   5.29s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.81s. Est. time left: 00:00:00:00
# Total run time:   5.81s
# Done.

# %%
delta_x_theory = np.linspace(-3*sigma, 3*sigma, 100)
overlap_theory = 0.5*(1- np.exp(- (delta_x_theory**2) / (2*sigma**2)))

fig, ax = plt.subplots(1,1, figsize=(4,4))
ax.plot(delta_x_tab, final_overlap_free_tab, 'o', label="Simulation", color='red')
ax.plot(delta_x_theory, overlap_theory, label="Theory", color="blue", alpha=0.5)
ax.set_xlabel(r"$\Delta x$")
ax.set_ylabel("Final overlap with free evolution")
ax.set_xticks(np.array([-3,-2, -1, 0, 1, 2,3])*sigma)
ax.set_xticklabels([r"$-3\sigma$", r"$-2\sigma$", r"$-\sigma$", "0", r"$\sigma$", r"$2\sigma$", r"$3\sigma$"])
ax.grid()
ax.legend()
plt.show()
